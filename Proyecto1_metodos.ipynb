# %% [markdown]
# # Flujo de potencia en una micro red.
# ## Metodos numericos
# ### Eugenio Aristondo
# ### Integrantes:
# Cristian palala
# Fabian Ortega
# Samuel Urbina
# René González
# Oscar Lucas
